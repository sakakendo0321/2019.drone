# %%
# %matplotlib inline
import time
import pylab as pl
from IPython import display
for i in range(10):
    pl.plot(pl.randn(100))
    display.clear_output(wait=True)
    display.display(pl.gcf())
    time.sleep(1.0)

# %%
#%matplotlib inline
# Queue
from random import randint
from collections import deque

#Plot
import matplotlib.pyplot as plt
from IPython.display import display, clear_output

# Queue
num = 10
queue = deque([0]*10)

# Plot
plt.ion()
fig = plt.figure()

for i in range(num):
    # Queue
    queue.popleft()
    queue.append(np.random.rand(1))

    # Plot
    clear_output(wait = True)
    plt.cla()
    plt.plot(range(i-9,i+1),queue)
    plt.grid()
    plt.ylim(0,1)
    display(fig)

# %%
#%matplotlib inline
import numpy as np
# Queue
from random import randint
from collections import deque

#Plot
import matplotlib.pyplot as plt
from IPython.display import display, clear_output

# Queue
num = 10
queue = deque([0]*10)

# Plot
plt.ion()
fig = plt.figure()

for i in range(num):
    # Queue
    queue.popleft()
#    queue.append(np.random.rand(1))
    queue.append(i/10)

    # Plot
    clear_output(wait = True)
    plt.cla()
    plt.plot(range(i-9,i+1),queue)
    plt.plot([1,2,3],[0.3,0.2,0.1])
    plt.grid()
    plt.ylim(0,1)
    display(fig)

# %%
from pyardrone import ARDrone

drone=ARDrone()
drone.navdata_ready.wait()
while not drone.state.fly_mask:
    drone.takeoff()
    print(drone.navdata.demo)
time.sleep(10)
while drone.state.fly_mask:
    drone.land()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-0af410c16679> in <module>
# ----> 1 from pyardrone import ARDrone
#       2
#       3 drone=ARDrone()
#       4 drone.navdata_ready.wait()
#       5 while not drone.state.fly_mask:
#
# ModuleNotFoundError: No module named 'pyardrone'
